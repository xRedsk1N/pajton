# %% [markdown]
# <a href="https://colab.research.google.com/github/xRedsk1N/pajton/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('ugh')
# Out:
# ugh

# %%
x = int(input("X: "))
y = int(input("Y: "))
print(x+y,x-y,x*y,x/y)
# Out:
# X: 6
# Y: 7
# 13 -1 42 0.8571428571428571
